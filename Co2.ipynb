# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
dataFrame = pd.read_excel("CO2 Emissions.xlsx")

# %%
dataFrame
# Out:
#       country_code country_name  year         value
# 0              ABW        Aruba  1960  11092.675000
# 1              ABW        Aruba  1961  11576.719000
# 2              ABW        Aruba  1962  12713.489000
# 3              ABW        Aruba  1963  12178.107000
# 4              ABW        Aruba  1964  11840.743000
# ...            ...          ...   ...           ...
# 13948          ZWE     Zimbabwe  2015  12430.000305
# 13949          ZWE     Zimbabwe  2016  11020.000458
# 13950          ZWE     Zimbabwe  2017  10340.000153
# 13951          ZWE     Zimbabwe  2018  12380.000114
# 13952          ZWE     Zimbabwe  2019  11760.000229
#
# [13953 rows x 4 columns]

# %%
turkey_data = dataFrame[dataFrame['country_name'] == 'Turkey']
china_data = dataFrame[dataFrame['country_name'] == 'China']

# %%
plt.figure(figsize=(10, 6))
plt.plot(turkey_data['year'], turkey_data['value'])
plt.title('Turkey CO2 Emissions Over Years')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (Million Metric Tons)')
plt.grid(True)

# %%
plt.plot(china_data["year"], china_data["value"])

# %%
# 'value' sütununu sıralayın
china_data_sorted = china_data.sort_values(by='value')

# Histogramı oluşturun
plt.hist(china_data_sorted["value"], bins='auto', color='blue', alpha=0.7)
plt.title('CO2 Emissions Distribution in China')
plt.xlabel('CO2 Emissions (Million Metric Tons)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
